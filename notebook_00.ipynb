# %% [markdown]
# # Notebook 0: Limpeza dos Dados
#
# Projeto Booklog
#
# Objetivo deste notebook:
# O dataset original (data.csv) retirado do Kaggle possui 100.000 registros de livros. No entanto, esses dados brutos contêm alguns valores ausentes que podem prejudicar as análises futuras.
#
# Este notebook foca exclusivamente na etapa de Pré-processamento. Ao final, exportaremos uma base de dados limpa para ser consumida pelos próximos notebooks de Análise Exploratória (EDA).

# %%
import pandas as pd
dadosBrutos = pd.read_parquet("datasets/data.parquet")
dadosBrutos.info()
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 dadosBrutos = pd.read_parquet("datasets/data.parquet")
#       3 dadosBrutos.info()
#
# File c:\Users\gabry\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)    510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
#    (...)    650     1    4    9
#     651     """
# --> 653     impl = get_engine(engine)
#     655     if use_nullable_dtypes is not lib.no_default:
#     656         msg = (
#     657             "The argument 'use_nullable_dtypes' is deprecated and will be removed "
#     658             "in a future version."
#     659         )
#
# File c:\Users\gabry\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File c:\Users\gabry\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File c:\Users\gabry\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\arrow\extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File c:\Users\gabry\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyarrow\types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File c:\Users\gabry\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined

# %%
colunasObrigatorias = [
    'title', 
    'author', 
    'genre',
    'desc', 
    'rating',
    'pages', 
    'totalratings',
    'reviews',
    'bookformat'
]
dadosLimpos = dadosBrutos.dropna(subset=colunasObrigatorias).copy()

linhasAntes = len(dadosBrutos)
linhasDepois = len(dadosLimpos)
print(f"Total de livros originais: {linhasAntes}")
print(f"Total de livros após limpeza: {linhasDepois}")
# Out:
# Total de livros originais: 100000
# Total de livros após limpeza: 84054

# %% [markdown]
# #Exportação do Dataset Tratado
#
# Com os dados limpos, exportamos o dataset tratado, assim, os futuros notebooks utilizarão este novo arquivo.

# %%
dadosLimpos.to_parquet("datasets/books.parquet", compression='snappy')

print(f"O arquivo books foi gerado.")
# Out:
# O arquivo books foi gerado.
